# %% [markdown]
# # Jupyter Notebook
# The Jupyter Notebook is an open-source web application that allows you to create and share documents that contain live code, equations, visualizations and narrative text. Uses include: data cleaning and transformation, numerical simulation, statistical modeling, data visualization, machine learning, and much more.
# - https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html#LaTeX-equations

# %%
# TODO: open in colab
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/berradais/dna-2020-2021/blob/master/0-Env/4.Notebook/.ipynb_checkpoints/4.1.notebook-checkpoint.ipynb)

# %% [markdown]
# ### Jupyter Notebook: Cell based IDE
#
# - Two type of cells : Markdown, and Code
# - Notebok has two modes : Edit mode and commande Mode (Use the click mouse or ESC to switch between mode). A lot of shortcut exit in the commande Mode
#     * A : cell creation before the current cell
#     * B : cell creation after the current cell
#     * DD : cell suppression
#     * Y : switch to code cell
#     * M : switch to markdown cell
#     * SHIFT + ENTER : execute the current cell
#     * ALT + ENTER : execute the current cell and create a new empty cell
#
# - Please visit : [https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/](https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/)

# %% [markdown]
# # Make some cell manipulation
# a = 1

# %%
a = 1
a
# Out:
# 1

# %% [markdown]
# # Markdown
#
#
# A way to style text on the web. You control the display of the document; formaing words as
# bold or italic, adding images, and creating lists are just a few of the things we can do with Markdown.

# %% [markdown]
# ### Headers

# %% [markdown]
# * # This is an
#
#  <h1> h1 tag </h1>
#
# * ## This is an
#
#  <h2> h2 tag </h2>
#
# * ###### This is an
#  <h6> h6 tag </h6>
#
#  ___

# %% [markdown]
# ### Lists

# %% [markdown]
# **Unordred list**
# * Item 1
# * Item 2
#     * Item 2a
#     * Item 2b
#
# **Ordred list**
# 1. Item 1
# 2. Item 2
# 3. Item 3
#     * Item 3a
#     * Item 3b

# %% [markdown]
# * My first item
#     + Second level
#         * Thrid level

# %% [markdown]
# ### Emphasis

# %% [markdown]
# 1. *This text will be italic*
#
# 2. _This will also be italic_
#
# 3. **This text will be bold**
#
# 4. __This will also be bold__
#
# 5. *You **can** combine them*
#
# 6. ``Italic``
#
# 7. ~~bared text.~~

# %% [markdown]
# ### Links
#
# * [Display text](#jupyter-notebook)
#
# * [wikipedia](https://en.wikipedia.org/wiki/Confounding)
#
# * https://en.wikipedia.org/wiki/Confounding

# %% [markdown]
# ### Examples of Images

# %% [markdown]
# Because images are so important Markdown Monster offers quite a few ways to embed images into a Markdown document:
#
#     - Type it in using Markdown ![](image.png) or HTML syntax
#     - Using the Embed Image Dialog to select images or Urls
#     - Paste images from the Clipboard
#     - Drag and Drop image files from the Folder Browser
#     - Drag and Drop image files from Explorer into the document
#     - Use the Screen Capture Tool to Capture Screen Shots
#
#
# The most used Format: ``![Alternative Text if the image can't be loaded](url)``

# %% [markdown]
# ![image.png](attachment:679445be-76d9-4f23-a6ae-b528687fc056.png)![image.png](attachment:c3e6c357-c100-4d1f-b8ed-f4028b8da735.png)

# %% [markdown]
# * ![Text to be displayed if the image is not loader](https://www.directwoodflooring.co.uk/media/catalog/product/cache/c486f3c3ca16cb41d29ab6285e057f37/f/a/farmhouse-whitelaminateflooring-1_1.jpg)

# %% [markdown]
# #### Ctrl +v based
# ![image.png](attachment:image.png)

# %% [markdown]
# #### `Html based`
# <img src="salll.jpg"
#      alt="Markdown Monster icon"
#      style="float: left; margin-right: 10px;" />

# %% [markdown]
# ####  `url based`
# ![My Image](salll.jpg)

# %% [markdown]
# ### Links
#
# http://github.com - automatic!
#
# or
#
# [GitHub](http://github.com)

# %% [markdown]
# ### Latex
#
# ```latex
# $x^2+y/3$
# ```
#
# * First item
# $x^2+y/3$
# * Second item
# $X_{12}$

# %% [markdown]
# ### Code and Syntax Highlighting

# %% [markdown]
# ```python
# >>>> a = 1
# >>>> print(a)
# ```
